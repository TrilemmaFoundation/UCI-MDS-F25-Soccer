# %%
import json
import matplotlib.pyplot as plt
import numpy as np


from google.colab import drive
import sqlite3
import pandas as pd

# 1. Mount drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Define shared file path
db_path = '/content/drive/MyDrive/statsbomb/statsbomb_euro2020.db'

# 3. Connect and query
conn = sqlite3.connect(db_path)
df = pd.read_sql_query("SELECT COUNT(*) FROM matches;", conn)

# 4. Display sample data
df.head()

# with open('15946.json', 'r') as f:
#   data = json.load(f)
# Out:
#    COUNT(*)
# 0        51

# %%
# tables in the dataset
tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
tables
# Out:
#               name
# 0          lineups
# 1  sqlite_sequence
# 2       frames_360
# 3          matches
# 4           events

# %%
# lineups table
lineups = pd.read_sql_query("SELECT * FROM lineups;", conn)
lineups.head()
# Out:
#    id  match_id  player_id                  player_name player_nickname  \
# 0   1   3788741       4355  Emerson Palmieri dos Santos         Emerson
# 1   2   3788741       6954            Giorgio Chiellini            None
# 2   3   3788741       6957                   Alex Meret            None
# 3   4   3788741       6964          Alessandro Florenzi            None
# 4   5   3788741       6993              Bryan Cristante            None
#
#    jersey_number country cards  \
# 0             13   Italy    []
# 1              3   Italy    []
# 2             26   Italy    []
# 3             24   Italy    []
# 4             16   Italy    []
#
#                                            positions team_name
# 0                                                 []     Italy
# 1  [{"end_reason": "Final Whistle", "from": "00:0...     Italy
# 2                                                 []     Italy
# 3  [{"end_reason": "Substitution - Off (Tactical)...     Italy
# 4  [{"end_reason": "Final Whistle", "from": "73:1...     Italy

# %%
# sqlite_sequence table
sqlite_sequence = pd.read_sql_query("SELECT * FROM sqlite_sequence;", conn)
sqlite_sequence.head()
# Out:
#       name   seq
# 0  lineups  2345

# %%
# frames_360 table
frames_360 = pd.read_sql_query("SELECT * FROM frames_360;", conn)
frames_360.head()
# Out:
#                                      id  match_id  \
# 0  5c888f58-fe77-459b-ab3b-a2fa5fb8ab16   3788741
# 1  5c888f58-fe77-459b-ab3b-a2fa5fb8ab16   3788741
# 2  5c888f58-fe77-459b-ab3b-a2fa5fb8ab16   3788741
# 3  5c888f58-fe77-459b-ab3b-a2fa5fb8ab16   3788741
# 4  5c888f58-fe77-459b-ab3b-a2fa5fb8ab16   3788741
#
#                                         visible_area  teammate  actor  keeper  \
# 0  [0.0, 27.7649873094419, 19.2332231959735, 17.3...         0      0       0
# 1  [0.0, 27.7649873094419, 19.2332231959735, 17.3...         0      0       0
# 2  [0.0, 27.7649873094419, 19.2332231959735, 17.3...         0      0       0
# 3  [0.0, 27.7649873094419, 19.2332231959735, 17.3...         0      0       0
# 4  [0.0, 27.7649873094419, 19.2332231959735, 17.3...         0      0       0
#
#                                   location
# 0   [43.65321648946649, 31.98843233703487]
# 1  [43.997359300214555, 45.59948277519069]
# 2  [49.675715677557776, 35.43426789099837]
# 3  [54.49371502803081, 30.093222782354946]
# 4   [58.27928594625963, 48.52844299605966]

# %%
# matches table
matches = pd.read_sql_query("SELECT * FROM matches;", conn)
matches.head()
# Out:
#    match_id  match_date      kick_off         competition season    home_team  \
# 0   3795108  2021-07-02  18:00:00.000  Europe - UEFA Euro   2020  Switzerland
# 1   3788769  2021-06-21  21:00:00.000  Europe - UEFA Euro   2020       Russia
# 2   3788766  2021-06-20  18:00:00.000  Europe - UEFA Euro   2020        Italy
# 3   3795220  2021-07-06  21:00:00.000  Europe - UEFA Euro   2020        Italy
# 4   3788761  2021-06-18  15:00:00.000  Europe - UEFA Euro   2020       Sweden
#
#   away_team  home_score  away_score match_status  ...  \
# 0     Spain           1           1    available  ...
# 1   Denmark           1           4    available  ...
# 2     Wales           1           0    available  ...
# 3     Spain           1           1    available  ...
# 4  Slovakia           1           0    available  ...
#
#              last_updated_360 match_week competition_stage  \
# 0  2023-04-27T21:55:08.695971          5    Quarter-finals
# 1  2023-04-27T22:20:21.686564          3       Group Stage
# 2  2023-04-27T22:22:42.769375          3       Group Stage
# 3            2022-08-04T12:00          6       Semi-finals
# 4  2023-04-27T22:28:52.986485          2       Group Stage
#
#                     stadium              referee         home_managers  \
# 0  Saint-Petersburg Stadium       Michael Oliver     Vladimir Petković
# 1                    Parken       Clément Turpin  Stanislav Cherchesov
# 2          Estadio Olímpico  Ovidiu Alin Hațegan       Roberto Mancini
# 3           Wembley Stadium          Felix Brych       Roberto Mancini
# 4  Saint-Petersburg Stadium       Daniel Siebert    Jan Olof Andersson
#
#                   away_managers data_version shot_fidelity_version  \
# 0  Luis Enrique Martínez García        1.1.0                     2
# 1               Kasper Hjulmand        1.1.0                     2
# 2                   Robert Page        1.1.0                     2
# 3  Luis Enrique Martínez García        1.1.0                     2
# 4               Štefan Tarkovič        1.1.0                     2
#
#   xy_fidelity_version
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
#
# [5 rows x 22 columns]

# %%
# events table
events = pd.read_sql_query("SELECT * FROM events;", conn)
events.head()
# Out:
#   fifty_fifty bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0        None               None                 None                    None
# 1        None               None                 None                    None
# 2        None               None                 None                    None
# 3        None               None                 None                    None
# 4        None               None                 None                    None
#
#   ball_recovery_recovery_failure block_deflection block_offensive  \
# 0                           None             None            None
# 1                           None             None            None
# 2                           None             None            None
# 3                           None             None            None
# 4                           None             None            None
#
#   block_save_block carry_end_location clearance_aerial_won  ...  \
# 0             None               None                 None  ...
# 1             None               None                 None  ...
# 2             None               None                 None  ...
# 3             None               None                 None  ...
# 4             None               None                 None  ...
#
#   substitution_outcome substitution_outcome_id substitution_replacement  \
# 0                 None                     NaN                     None
# 1                 None                     NaN                     None
# 2                 None                     NaN                     None
# 3                 None                     NaN                     None
# 4                 None                     NaN                     None
#
#   substitution_replacement_id  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                              tactics    team team_id  \
# 0  {"formation": 4141.0, "lineup": [{"jersey_numb...  Turkey     909
# 1  {"formation": 433.0, "lineup": [{"jersey_numbe...   Italy     914
# 2                                               None  Turkey     909
# 3                                               None   Italy     914
# 4                                               None  Turkey     909
#
#       timestamp         type under_pressure
# 0  00:00:00.000  Starting XI           None
# 1  00:00:00.000  Starting XI           None
# 2  00:00:00.000   Half Start           None
# 3  00:00:00.000   Half Start           None
# 4  00:00:00.000   Half Start           None
#
# [5 rows x 115 columns]

# %%
# we're going to use the first match
print(f"There are {len(events.columns)} events in this game.")
print(events.columns.tolist())
# Out:
# There are 115 events in this game.
# ['fifty_fifty', 'bad_behaviour_card', 'ball_receipt_outcome', 'ball_recovery_offensive', 'ball_recovery_recovery_failure', 'block_deflection', 'block_offensive', 'block_save_block', 'carry_end_location', 'clearance_aerial_won', 'clearance_body_part', 'clearance_head', 'clearance_left_foot', 'clearance_other', 'clearance_right_foot', 'counterpress', 'dribble_no_touch', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun', 'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage', 'foul_committed_card', 'foul_committed_offensive', 'foul_committed_penalty', 'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive', 'foul_won_penalty', 'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_lost_in_play', 'goalkeeper_outcome', 'goalkeeper_penalty_saved_to_post', 'goalkeeper_position', 'goalkeeper_punched_out', 'goalkeeper_shot_saved_off_target', 'goalkeeper_shot_saved_to_post', 'goalkeeper_success_in_play', 'goalkeeper_technique', 'goalkeeper_type', 'id', 'index_num', 'injury_stoppage_in_chain', 'interception_outcome', 'location', 'match_id', 'minute', 'miscontrol_aerial_won', 'off_camera', 'out_play', 'pass_aerial_won', 'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross', 'pass_cut_back', 'pass_deflected', 'pass_end_location', 'pass_goal_assist', 'pass_height', 'pass_inswinging', 'pass_length', 'pass_miscommunication', 'pass_no_touch', 'pass_outcome', 'pass_outswinging', 'pass_recipient', 'pass_recipient_id', 'pass_shot_assist', 'pass_straight', 'pass_switch', 'pass_technique', 'pass_through_ball', 'pass_type', 'period', 'play_pattern', 'player', 'player_id', 'player_off_permanent', 'position', 'possession', 'possession_team', 'possession_team_id', 'related_events', 'second', 'shot_aerial_won', 'shot_body_part', 'shot_deflected', 'shot_end_location', 'shot_first_time', 'shot_follows_dribble', 'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one', 'shot_open_goal', 'shot_outcome', 'shot_redirect', 'shot_saved_off_target', 'shot_saved_to_post', 'shot_statsbomb_xg', 'shot_technique', 'shot_type', 'substitution_outcome', 'substitution_outcome_id', 'substitution_replacement', 'substitution_replacement_id', 'tactics', 'team', 'team_id', 'timestamp', 'type', 'under_pressure']

# %%
# unique_teams in events table
unique_teams = events['team'].unique()
print("Unique teams in the events table:")
print(unique_teams)
# Out:
# Unique teams in the events table:
# ['Turkey' 'Italy' 'Denmark' 'Finland' 'Belgium' 'Russia' 'Wales'
#  'Switzerland' 'England' 'Croatia' 'Netherlands' 'Ukraine' 'Austria'
#  'North Macedonia' 'Scotland' 'Czech Republic' 'Poland' 'Slovakia' 'Spain'
#  'Sweden' 'France' 'Germany' 'Hungary' 'Portugal']

# %%
# event 0
pass_idx = []
pass_pos = []
rec_idx = []
rec_pos = []
shot_idx = []
shot_pos = []

for i, dat in enumerate(data):
  if int(dat['minute']) > 120:
    continue
  if data[i]['possession_team']['name'] == 'Barcelona':
    continue
  if dat['type']['name'] == 'Pass':
    pass_idx += [i]
    pass_pos += [dat['location']]
  elif dat['type']['name'] == 'Ball Receipt*':
    rec_idx += [i]
    rec_pos += [dat['location']]
  elif dat['type']['name'] == 'Shot':
    shot_idx += [i]
    shot_pos += [dat['location']]

fig, ax = plt.subplots()

ax.set_xlim(0, 120)
ax.set_ylim(0, 80)

ax.scatter([shot_pos[i][0] for i in range(len(shot_pos))], [shot_pos[i][1] for i in range(len(shot_pos))], s=1)
plt.show()

# %%
import datetime
times = []

for dat in data:
  times += [datetime.datetime.strptime(dat['timestamp'], '%H:%M:%S.%f')]

plt.plot(times)
plt.show()

# %%
map_interest = shot_pos

x = [map_interest[i][0] for i in range(len(map_interest))]
y = [map_interest[i][1] for i in range(len(map_interest))]

heatmap, xedges, yedges = np.histogram2d(x, y, range=[[0,120], [0,80]], bins=50)
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

scale = 4
fig, ax = plt.subplots(figsize=(2*scale,3*scale))
ax.set_xlim(0,120)
ax.set_ylim(0,80)
ax.imshow(heatmap.T, extent=extent, origin='lower', cmap='turbo')
plt.show()

# %%
extent
# Out:
# [np.float64(0.0), np.float64(120.0), np.float64(0.0), np.float64(80.0)]

# %%
all_types = []

for dat in data:
  if dat['type']['name'] in all_types:
    continue
  all_types += [dat['type']['name']]


all_types
# Out:
# ['Starting XI',
#  'Half Start',
#  'Pass',
#  'Ball Receipt*',
#  'Carry',
#  'Duel',
#  'Ball Recovery',
#  'Pressure',
#  'Miscontrol',
#  'Block',
#  'Interception',
#  'Shot',
#  'Goal Keeper',
#  'Clearance',
#  'Dispossessed',
#  'Dribble',
#  'Foul Committed',
#  'Foul Won',
#  'Dribbled Past',
#  'Bad Behaviour',
#  'Half End',
#  'Substitution',
#  'Tactical Shift',
#  'Error']

# %%
img = plt.imread('soccer-field.jpg')

fig, ax = plt.subplots(figsize = (12,8))
ax.imshow(img, extent=[-4,125,-2,81], aspect='auto')
ax.imshow(heatmap.T, extent=extent, origin='lower', cmap='turbo', alpha=0.4)
plt.title('Heatmap of Shots on Soccer Field')
plt.show()

# %%
img = plt.imread('soccer-field.jpg')

fig, ax = plt.subplots(figsize = (12,8))
ax.imshow(img, extent=[-4,125,-2,81], aspect='auto')
ax.imshow(heatmap.T, extent=extent, origin='lower', cmap='turbo', alpha=0.4)
plt.title('Heatmap of Passes on Soccer Field')
plt.show()

# %%
img = plt.imread('soccer-field.jpg')

fig, ax = plt.subplots(figsize = (12,8))
ax.imshow(img, extent=[-4,125,-2,81], aspect='auto')
ax.imshow(heatmap.T, extent=extent, origin='lower', cmap='turbo', alpha=0.4)
plt.title('Heatmap of Ball Receipts on Soccer Field')
plt.show()

# %% [markdown]
# Trying some generic code for matches

# %%
# # Choose a match (example: Russia vs Denmark)
# match_info = pd.read_sql_query("""
# SELECT match_id, home_team, away_team, home_score, away_score, match_date
# FROM matches
# WHERE home_team = 'Russia' AND away_team = 'Denmark';
# """, conn)

# print("Match info:")
# print(match_info)

# # Extract the match_id
# match_id = int(match_info.iloc[0]['match_id'])
# print(f"\nSelected match_id: {match_id}")

# # Load all events for this match
# events = pd.read_sql_query(f"""
# SELECT type, team, location_x, location_y, minute, second
# FROM events
# WHERE match_id = {match_id}
#   AND location_x IS NOT NULL
#   AND location_y IS NOT NULL;
# """, conn)

# print("\nEvent sample:")
# events.head()




# Load all events for this match (Russia vs Denmark)
events = pd.read_sql_query(f"""
SELECT type, team, location, pass_end_location, shot_end_location, carry_end_location
FROM events
WHERE match_id = 3788769;
""", conn)

# Helper to parse "[x, y]" or JSON-like strings
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def parse_loc(value):
    if value is None:
        return None, None
    try:
        loc = json.loads(value)
        if isinstance(loc, list) and len(loc) >= 2:
            return float(loc[0]), float(loc[1])
        else:
            return None, None
    except:
        try:
            vals = value.strip('[]').split(',')
            return float(vals[0]), float(vals[1])
        except:
            return None, None

# Create unified start position from `location`
events['location_x'], events['location_y'] = zip(*events['location'].map(parse_loc))
events = events.dropna(subset=['location_x', 'location_y']).copy()

print("Teams found:", events["team"].unique())
events.head(5)
# Out:
# Teams found: ['Russia' 'Denmark']
#     type     team      location pass_end_location shot_end_location  \
# 6   Pass   Russia  [60.0, 40.0]      [38.9, 38.7]              None
# 7   Pass   Russia  [39.6, 38.9]       [92.5, 6.7]              None
# 8   Pass   Russia   [75.8, 0.1]       [88.1, 3.7]              None
# 9   Pass  Denmark  [31.1, 76.7]      [22.6, 58.6]              None
# 10  Pass  Denmark  [22.8, 56.3]      [22.4, 32.2]              None
#
#    carry_end_location  location_x  location_y
# 6                None        60.0        40.0
# 7                None        39.6        38.9
# 8                None        75.8         0.1
# 9                None        31.1        76.7
# 10               None        22.8        56.3

# %%
# Replace with the exact names from previous print
team_a = "Russia"
team_b = "Denmark"

# Filter events for both teams
passes_a = events[(events['type'] == 'Pass') & (events['team'] == team_a)]
passes_b = events[(events['type'] == 'Pass') & (events['team'] == team_b)]

shots_a = events[(events['type'] == 'Shot') & (events['team'] == team_a)]
shots_b = events[(events['type'] == 'Shot') & (events['team'] == team_b)]

receipts_a = events[(events['type'] == 'Ball Receipt*') & (events['team'] == team_a)]
receipts_b = events[(events['type'] == 'Ball Receipt*') & (events['team'] == team_b)]

print(f"{team_a}: {len(passes_a)} passes, {len(shots_a)} shots, {len(receipts_a)} receipts")
print(f"{team_b}: {len(passes_b)} passes, {len(shots_b)} shots, {len(receipts_b)} receipts")
# Out:
# Russia: 289 passes, 6 shots, 267 receipts
# Denmark: 542 passes, 16 shots, 525 receipts

# %%
def side_by_side_heatmap(x1, y1, x2, y2, team1, team2, title, cmap1='turbo', cmap2='turbo'):
    """
    Generate side-by-side 2D histograms for two teams.
    """
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))

    for ax, x, y, team, cmap in zip(axes, [x1, x2], [y1, y2], [team1, team2], [cmap1, cmap2]):
        heatmap, xedges, yedges = np.histogram2d(x, y, range=[[0,120],[0,80]], bins=50)
        extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
        im = ax.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap)
        ax.set_xlim(0,120)
        ax.set_ylim(0,80)
        ax.set_xlabel("Pitch X (0–120)")
        ax.set_ylabel("Pitch Y (0–80)")
        ax.set_title(f"{team}", fontsize=14)
        fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

side_by_side_heatmap(
    passes_a['location_x'], passes_a['location_y'],
    passes_b['location_x'], passes_b['location_y'],
    team_a, team_b, title="Pass Locations — Russia vs Denmark"
)

side_by_side_heatmap(
    shots_a['location_x'], shots_a['location_y'],
    shots_b['location_x'], shots_b['location_y'],
    team_a, team_b, title="Shot Locations — Russia vs Denmark"
)

side_by_side_heatmap(
    receipts_a['location_x'], receipts_a['location_y'],
    receipts_b['location_x'], receipts_b['location_y'],
    team_a, team_b, title="Ball Receipts — Russia vs Denmark"
)

# %%
img = plt.imread('soccer-field.jpg')

def overlay_side_by_side(x1, y1, x2, y2, team1, team2, title, alpha=0.4, cmap1='turbo', cmap2='turbo'):
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))

    for ax, x, y, team, cmap in zip(axes, [x1, x2], [y1, y2], [team1, team2], [cmap1, cmap2]):
        heatmap, xedges, yedges = np.histogram2d(x, y, range=[[0,120],[0,80]], bins=50)
        extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

        ax.imshow(img, extent=[-4, 125, -2, 81], aspect='auto')
        ax.imshow(heatmap.T, extent=extent, origin='lower', cmap=cmap, alpha=alpha)
        ax.set_xlim(0,120)
        ax.set_ylim(0,80)
        ax.set_xlabel("Pitch X (0–120)")
        ax.set_ylabel("Pitch Y (0–80)")
        ax.set_title(f"{team}", fontsize=14)

    plt.suptitle(title, fontsize=16)
    plt.tight_layout()
    plt.show()

overlay_side_by_side(
    passes_a['location_x'], passes_a['location_y'],
    passes_b['location_x'], passes_b['location_y'],
    team_a, team_b, title="Pass Heatmaps — Russia vs Denmark"
)

overlay_side_by_side(
    shots_a['location_x'], shots_a['location_y'],
    shots_b['location_x'], shots_b['location_y'],
    team_a, team_b, title="Shot Heatmaps — Russia vs Denmark"
)

overlay_side_by_side(
    receipts_a['location_x'], receipts_a['location_y'],
    receipts_b['location_x'], receipts_b['location_y'],
    team_a, team_b, title="Receipts Heatmaps — Russia vs Denmark"
)
